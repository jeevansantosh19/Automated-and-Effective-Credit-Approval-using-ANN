# %%
# Import the Required Libraries for Data Analysis
import numpy as np
import pandas as pd

# Supress the warning
import warnings
warnings.filterwarnings('ignore')

# %%
# Upload the Required Dataset
credit_data = pd.read_csv('credit_approval.csv')
credit_data
# Out:
#                  name              city  income  credit_score  loan_amount  \
# 0        Allison Hill         East Jill  113810           389        39698
# 1        Brandon Hall     New Jamesside   44592           729        15446
# 2        Rhonda Smith      Lake Roberto   33278           584        11189
# 3     Gabrielle Davis  West Melanieview  127196           344        48823
# 4        Valerie Gray         Mariastad   66048           496        47174
# ...               ...               ...     ...           ...          ...
# 1995   James Schaefer         Robertton   92163           770        12251
# 1996        Diana Lin         New Frank   38799           635        48259
# 1997    Brandon Meyer        East Haley   41957           763        16752
# 1998      Jason Price          Adamland  139022           360        24031
# 1999     Nicole Brown    New Nathantown   41188           482        31397
#
#       years_employed  points  loan_approved
# ...

# %%
# Display First 10 Rows of a Dataset
credit_data.head(10)
# Out:
#               name              city  income  credit_score  loan_amount  \
# 0     Allison Hill         East Jill  113810           389        39698
# 1     Brandon Hall     New Jamesside   44592           729        15446
# 2     Rhonda Smith      Lake Roberto   33278           584        11189
# 3  Gabrielle Davis  West Melanieview  127196           344        48823
# 4     Valerie Gray         Mariastad   66048           496        47174
# 5   Darren Roberts   Port Jesseville   62098           689        19217
# 6       Holly Wood       Lake Joseph   59256           373        40920
# 7  Nicholas Martin        Nelsonside   48289           524        45866
# 8      Patty Perez   Port Leslieview  126530           367        14826
# 9       Emily Rios    Wilkersonmouth   43434           446        18359
#
#    years_employed  points  loan_approved
# 0              27    50.0          False
# 1              28    55.0          False
# 2              13    45.0          False
# ...

# %%
# Display Last 10 Rows of a Dataset
credit_data.tail(10)
# Out:
#                       name              city  income  credit_score  \
# 1990        Rebecca Newman  West Christopher  117177           712
# 1991  Christopher Morrison         Cookshire   63408           376
# 1992         Sierra Gentry      Jenniferstad   79060           572
# 1993         Hannah Carter           Basston   50006           626
# 1994           Ryan Thomas         Tylertown  120023           318
# 1995        James Schaefer         Robertton   92163           770
# 1996             Diana Lin         New Frank   38799           635
# 1997         Brandon Meyer        East Haley   41957           763
# 1998           Jason Price          Adamland  139022           360
# 1999          Nicole Brown    New Nathantown   41188           482
#
#       loan_amount  years_employed  points  loan_approved
# 1990        10028              27    85.0           True
# 1991        30443               3    25.0          False
# 1992         9643               6    45.0          False
# ...

# %%
# Rename the Old Columns into New Columns
credit_data = credit_data.rename(
    columns = {
        'name' : 'Name',
        'city' : 'City',
        'income' : 'Income',
        'credit_score' : 'Credit Score',
        'loan_amount' : 'Loan Amount',
        'years_employed' : 'Years Employed',
        'points' : 'Points',
        'loan_approved' : 'Loan Approved'
    })
credit_data
# Out:
#                  Name              City  Income  Credit Score  Loan Amount  \
# 0        Allison Hill         East Jill  113810           389        39698
# 1        Brandon Hall     New Jamesside   44592           729        15446
# 2        Rhonda Smith      Lake Roberto   33278           584        11189
# 3     Gabrielle Davis  West Melanieview  127196           344        48823
# 4        Valerie Gray         Mariastad   66048           496        47174
# ...               ...               ...     ...           ...          ...
# 1995   James Schaefer         Robertton   92163           770        12251
# 1996        Diana Lin         New Frank   38799           635        48259
# 1997    Brandon Meyer        East Haley   41957           763        16752
# 1998      Jason Price          Adamland  139022           360        24031
# 1999     Nicole Brown    New Nathantown   41188           482        31397
#
#       Years Employed  Points  Loan Approved
# ...

# %%
# Display the Names of a Columns
credit_data.columns
# Out:
# Index(['Name', 'City', 'Income', 'Credit Score', 'Loan Amount',
#        'Years Employed', 'Points', 'Loan Approved'],
#       dtype='object')

# %%
# Display the dimensions of a Dataset
credit_data.shape
# Out:
# (2000, 8)

# %%
# Detect the Data-Type of a every column in a dataset
credit_data.dtypes
# Out:
# Name               object
# City               object
# Income              int64
# Credit Score        int64
# Loan Amount         int64
# Years Employed      int64
# Points            float64
# Loan Approved        bool
# dtype: object

# %%
# Display the k=length of a Dataset
print(len(credit_data))
# Out:
# 2000

# %%
# Detect the type of a Dataset
type(credit_data)
# Out:
# pandas.core.frame.DataFrame

# %%
# Display the Information of a Dataset
credit_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            2000 non-null   object
#  1   City            2000 non-null   object
#  2   Income          2000 non-null   int64
#  3   Credit Score    2000 non-null   int64
#  4   Loan Amount     2000 non-null   int64
#  5   Years Employed  2000 non-null   int64
#  6   Points          2000 non-null   float64
#  7   Loan Approved   2000 non-null   bool
# dtypes: bool(1), float64(1), int64(4), object(2)
# memory usage: 111.5+ KB

# %%
# Display the Statistical Summary of a Dataset
credit_data.describe()
# Out:
#               Income  Credit Score   Loan Amount  Years Employed       Points
# count    2000.000000   2000.000000   2000.000000     2000.000000  2000.000000
# mean    90585.977000    573.946000  25308.503000       20.441000    56.680000
# std     34487.874907    160.564945  14207.320147       11.777813    18.638033
# min     30053.000000    300.000000   1022.000000        0.000000    10.000000
# 25%     61296.250000    433.000000  12748.750000       10.000000    45.000000
# 50%     90387.500000    576.000000  25661.500000       21.000000    55.000000
# 75%    120099.750000    715.000000  37380.500000       31.000000    70.000000
# max    149964.000000    850.000000  49999.000000       40.000000   100.000000

# %%
credit_data.describe().T
# Out:
#                  count       mean           std      min       25%      50%  \
# Income          2000.0  90585.977  34487.874907  30053.0  61296.25  90387.5
# Credit Score    2000.0    573.946    160.564945    300.0    433.00    576.0
# Loan Amount     2000.0  25308.503  14207.320147   1022.0  12748.75  25661.5
# Years Employed  2000.0     20.441     11.777813      0.0     10.00     21.0
# Points          2000.0     56.680     18.638033     10.0     45.00     55.0
#
#                       75%       max
# Income          120099.75  149964.0
# Credit Score       715.00     850.0
# Loan Amount      37380.50   49999.0
# Years Employed      31.00      40.0
# Points              70.00     100.0

# %%
# Change the Datatype of last column
credit_data['Loan Approved'] = credit_data['Loan Approved'].astype('object')
credit_data['Loan Approved']
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1995     True
# 1996    False
# 1997     True
# 1998    False
# 1999    False
# Name: Loan Approved, Length: 2000, dtype: object

# %%
# Drop the Categorical Columns
cat_columns = ['Name', 'City']

credit_data = credit_data.drop(cat_columns, axis = 1)

# %%
credit_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Income          2000 non-null   int64
#  1   Credit Score    2000 non-null   int64
#  2   Loan Amount     2000 non-null   int64
#  3   Years Employed  2000 non-null   int64
#  4   Points          2000 non-null   float64
#  5   Loan Approved   2000 non-null   object
# dtypes: float64(1), int64(4), object(1)
# memory usage: 93.9+ KB

# %%
# Replacing the Values
credit_data['Loan Approved'] = credit_data['Loan Approved'].replace({
    True: 'Yes',
    False: 'No'
})
credit_data['Loan Approved']
# Out:
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 1995    Yes
# 1996     No
# 1997    Yes
# 1998     No
# 1999     No
# Name: Loan Approved, Length: 2000, dtype: object

# %%
credit_data
# Out:
#       Income  Credit Score  Loan Amount  Years Employed  Points Loan Approved
# 0     113810           389        39698              27    50.0            No
# 1      44592           729        15446              28    55.0            No
# 2      33278           584        11189              13    45.0            No
# 3     127196           344        48823              29    50.0            No
# 4      66048           496        47174               4    25.0            No
# ...      ...           ...          ...             ...     ...           ...
# 1995   92163           770        12251              13    85.0           Yes
# 1996   38799           635        48259              17    40.0            No
# 1997   41957           763        16752               5    60.0           Yes
# 1998  139022           360        24031              35    55.0            No
# 1999   41188           482        31397               6    20.0            No
#
# [2000 rows x 6 columns]

# %%
# Value Counts in Every Column (Categorical)
credit_data['Loan Approved'].value_counts()
# Out:
# Loan Approved
# No     1121
# Yes     879
# Name: count, dtype: int64

# %%
# Correlation
num_columns = ['Income', 'Credit Score', 'Loan Amount', 'Years Employed', 'Points']
credit_data[num_columns].corr()
# Out:
#                   Income  Credit Score  Loan Amount  Years Employed    Points
# Income          1.000000     -0.027113     0.037612       -0.014441  0.451142
# Credit Score   -0.027113      1.000000    -0.008076        0.023598  0.740899
# Loan Amount     0.037612     -0.008076     1.000000        0.013015 -0.223039
# Years Employed -0.014441      0.023598     0.013015        1.000000  0.156441
# Points          0.451142      0.740899    -0.223039        0.156441  1.000000

# %%
# Covariance
credit_data.cov(numeric_only = True)
# Out:
#                       Income   Credit Score   Loan Amount  Years Employed  \
# Income          1.189414e+09 -150137.935710  1.842910e+07    -5865.865790
# Credit Score   -1.501379e+05   25781.101635 -1.842379e+04       44.625627
# Loan Amount     1.842910e+07  -18423.785731  2.018479e+08     2177.830592
# Years Employed -5.865866e+03      44.625627  2.177831e+03      138.716877
# Points          2.899875e+05    2217.224332 -5.905986e+04       34.341291
#
#                        Points
# Income          289987.549915
# Credit Score      2217.224332
# Loan Amount     -59059.862471
# Years Employed      34.341291
# Points             347.376288

# %%
# Static Functions (Sum)
print(credit_data['Income'].sum())
print(credit_data['Credit Score'].sum())
print(credit_data['Loan Amount'].sum())
print(credit_data['Years Employed'].sum())
print(credit_data['Points'].sum())
# Out:
# 181171954
# 1147892
# 50617006
# 40882
# 113360.0

# %%
# Static Functions (Cummulative Sum)
print(credit_data['Income'].cumsum())
print(credit_data['Credit Score'].cumsum())
print(credit_data['Loan Amount'].cumsum())
print(credit_data['Years Employed'].cumsum())
print(credit_data['Points'].cumsum())
# Out:
# 0          113810
# 1          158402
# 2          191680
# 3          318876
# 4          384924
#           ...
# 1995    180910988
# 1996    180949787
# 1997    180991744
# 1998    181130766
# 1999    181171954
# Name: Income, Length: 2000, dtype: int64
# 0           389
# 1          1118
# 2          1702
# 3          2046
# 4          2542
#          ...
# 1995    1145652
# 1996    1146287
# 1997    1147050
# 1998    1147410
# 1999    1147892
# Name: Credit Score, Length: 2000, dtype: int64
# 0          39698
# 1          55144
# 2          66333
# 3         115156
# 4         162330
#           ...
# 1995    50496567
# 1996    50544826
# 1997    50561578
# 1998    50585609
# 1999    50617006
# Name: Loan Amount, Length: 2000, dtype: int64
# 0          27
# 1          55
# 2          68
# 3          97
# 4         101
#         ...
# 1995    40819
# 1996    40836
# 1997    40841
# 1998    40876
# 1999    40882
# Name: Years Employed, Length: 2000, dtype: int64
# ...

# %%
# Static Functions (Mean)
print(credit_data['Income'].mean())
print(credit_data['Credit Score'].mean())
print(credit_data['Loan Amount'].mean())
print(credit_data['Years Employed'].mean())
print(credit_data['Points'].mean())
# Out:
# 90585.977
# 573.946
# 25308.503
# 20.441
# 56.68

# %%
# Static Functions (Median)
print(credit_data['Income'].median())
print(credit_data['Credit Score'].median())
print(credit_data['Loan Amount'].median())
print(credit_data['Years Employed'].median())
print(credit_data['Points'].median())
# Out:
# 90387.5
# 576.0
# 25661.5
# 21.0
# 55.0

# %%
# Static Functions (Variance)
print(credit_data['Income'].var())
print(credit_data['Credit Score'].var())
print(credit_data['Loan Amount'].var())
print(credit_data['Years Employed'].var())
print(credit_data['Points'].var())
# Out:
# 1189413515.5962691
# 25781.10163481741
# 201847945.75486842
# 138.71687743871937
# 347.3762881440721

# %%
# Static Functions (Standard Deviation)
print(credit_data['Income'].std())
print(credit_data['Credit Score'].std())
print(credit_data['Loan Amount'].std())
print(credit_data['Years Employed'].std())
print(credit_data['Points'].std())
# Out:
# 34487.874906933146
# 160.56494522409744
# 14207.320146842205
# 11.777812931046212
# 18.638033376514596

# %%
# Static Functions (Mode)
print(credit_data['Income'].mode())
print(credit_data['Credit Score'].mode())
print(credit_data['Loan Amount'].mode())
print(credit_data['Years Employed'].mode())
print(credit_data['Points'].mode())
# Out:
# 0    104177
# Name: Income, dtype: int64
# 0    395
# 1    468
# 2    546
# 3    645
# Name: Credit Score, dtype: int64
# 0      1774
# 1      9800
# 2     13826
# 3     14149
# 4     14353
# 5     15295
# 6     15565
# 7     16848
# 8     18041
# 9     18387
# 10    24085
# 11    24674
# 12    24758
# 13    26289
# 14    26392
# 15    27234
# 16    27571
# 17    28119
# 18    30443
# 19    34222
# 20    35339
# 21    38574
# 22    40749
# 23    41616
# 24    42698
# 25    44477
# 26    46238
# 27    46642
# 28    46916
# 29    48404
# 30    48578
# 31    49065
# Name: Loan Amount, dtype: int64
# 0    23
# Name: Years Employed, dtype: int64
# 0    50.0
# Name: Points, dtype: float64

# %%
# Import the Required Libraries for Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Box Plot
plt.figure(figsize = (12, 10))
sns.boxplot(credit_data['Income'])
plt.title('Income')
plt.show()

# %%
# Box Plot
plt.figure(figsize = (12, 10))
sns.boxplot(credit_data['Credit Score'], color = 'red')
plt.title('Credit Score')
plt.show()

# %%
# Box Plot
plt.figure(figsize = (12, 10))
sns.boxplot(credit_data['Points'], color = 'green')
plt.title('Points')
plt.show()

# %%
# Box Plot
plt.figure(figsize = (12, 10))
sns.boxplot(credit_data['Years Employed'], color = 'magenta')
plt.title('Years Employed')
plt.show()

# %%
# Box Plot
plt.figure(figsize = (12, 10))
sns.boxplot(credit_data['Loan Amount'], color = 'yellow')
plt.title('Loan Amount')
plt.show()

# %%
# Importing the Required Libraries for Preprocessing, Standardizing and Encoding
import sklearn
from sklearn.preprocessing import MinMaxScaler, LabelEncoder

# %%
# Min Max Scaler
mms = MinMaxScaler()
mms
# Out:
# MinMaxScaler()

# %%
# Label Encoder
le = LabelEncoder()
le
# Out:
# LabelEncoder()

# %%
# Standardize the Numeric Columns
credit_data[num_columns] = mms.fit_transform(credit_data[num_columns])
credit_data[num_columns]
# Out:
#         Income  Credit Score  Loan Amount  Years Employed    Points
# 0     0.698493      0.161818     0.789677           0.675  0.444444
# 1     0.121248      0.780000     0.294506           0.700  0.500000
# 2     0.026895      0.516364     0.207587           0.325  0.388889
# 3     0.810126      0.080000     0.975989           0.725  0.444444
# 4     0.300181      0.356364     0.942320           0.100  0.166667
# ...        ...           ...          ...             ...       ...
# 1995  0.517967      0.854545     0.229271           0.325  0.833333
# 1996  0.072937      0.609091     0.964473           0.425  0.333333
# 1997  0.099274      0.841818     0.321171           0.125  0.555556
# 1998  0.908749      0.109091     0.469792           0.875  0.500000
# 1999  0.092861      0.330909     0.620189           0.150  0.111111
#
# [2000 rows x 5 columns]

# %%
credit_data['Loan Approved'] = le.fit_transform(credit_data['Loan Approved'])
credit_data['Loan Approved']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1995    1
# 1996    0
# 1997    1
# 1998    0
# 1999    0
# Name: Loan Approved, Length: 2000, dtype: int64

# %%
# Feature Variable
X = credit_data.drop(['Loan Approved'], axis = 1)
X
# Out:
#         Income  Credit Score  Loan Amount  Years Employed    Points
# 0     0.698493      0.161818     0.789677           0.675  0.444444
# 1     0.121248      0.780000     0.294506           0.700  0.500000
# 2     0.026895      0.516364     0.207587           0.325  0.388889
# 3     0.810126      0.080000     0.975989           0.725  0.444444
# 4     0.300181      0.356364     0.942320           0.100  0.166667
# ...        ...           ...          ...             ...       ...
# 1995  0.517967      0.854545     0.229271           0.325  0.833333
# 1996  0.072937      0.609091     0.964473           0.425  0.333333
# 1997  0.099274      0.841818     0.321171           0.125  0.555556
# 1998  0.908749      0.109091     0.469792           0.875  0.500000
# 1999  0.092861      0.330909     0.620189           0.150  0.111111
#
# [2000 rows x 5 columns]

# %%
# Target Varible
y = credit_data.iloc[:, -1]
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1995    1
# 1996    0
# 1997    1
# 1998    0
# 1999    0
# Name: Loan Approved, Length: 2000, dtype: int64

# %%
credit_data
# Out:
#         Income  Credit Score  Loan Amount  Years Employed    Points  \
# 0     0.698493      0.161818     0.789677           0.675  0.444444
# 1     0.121248      0.780000     0.294506           0.700  0.500000
# 2     0.026895      0.516364     0.207587           0.325  0.388889
# 3     0.810126      0.080000     0.975989           0.725  0.444444
# 4     0.300181      0.356364     0.942320           0.100  0.166667
# ...        ...           ...          ...             ...       ...
# 1995  0.517967      0.854545     0.229271           0.325  0.833333
# 1996  0.072937      0.609091     0.964473           0.425  0.333333
# 1997  0.099274      0.841818     0.321171           0.125  0.555556
# 1998  0.908749      0.109091     0.469792           0.875  0.500000
# 1999  0.092861      0.330909     0.620189           0.150  0.111111
#
#       Loan Approved
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# ...

# %%
credit_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Income          2000 non-null   float64
#  1   Credit Score    2000 non-null   float64
#  2   Loan Amount     2000 non-null   float64
#  3   Years Employed  2000 non-null   float64
#  4   Points          2000 non-null   float64
#  5   Loan Approved   2000 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 93.9 KB

# %%
# Histogram
plt.figure(figsize=(12, 10))
sns.histplot(data=credit_data, x='Loan Amount', hue='Loan Approved', bins=10, kde=True)
plt.title('Loan Amount Distribution by Loan Approval')
plt.xlabel('Loan Amount')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(12, 10))
sns.boxplot(data=credit_data, x='Loan Approved', y='Loan Amount')
plt.title('Loan Amount by Loan Approval Status')
plt.xlabel('Loan Approved')
plt.ylabel('Loan Amount')
plt.show()

# %%
# Violin Plot
plt.figure(figsize=(12, 6))
sns.violinplot(data=credit_data, x='Loan Approved', y='Income')
plt.xticks(rotation=45)
plt.title('Income Distribution for Approval of Loans')
plt.show()

# %%
# Scatter Plot
sns.scatterplot(data=credit_data, x='Credit Score', y='Points', hue='Loan Approved')
plt.title('Credit Score vs Points Colored by Approval')
plt.show()

# %%
# Divide Into Training and Testing Datasets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.15, random_state = 42)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1700, 5)
# (300, 5)
# (1700,)
# (300,)

# %%
X_train.dtypes
# Out:
# Income            float64
# Credit Score      float64
# Loan Amount       float64
# Years Employed    float64
# Points            float64
# dtype: object

# %%
X_test.dtypes
# Out:
# Income            float64
# Credit Score      float64
# Loan Amount       float64
# Years Employed    float64
# Points            float64
# dtype: object

# %%
y_train.dtypes
# Out:
# dtype('int64')

# %%
y_test.dtypes
# Out:
# dtype('int64')

# %%
# Scale on X_train
X_train_scaled = mms.fit_transform(X_train)
X_train_scaled
# Out:
# array([[0.16849163, 0.25090909, 0.52551198, 0.65      , 0.27777778],
#        [0.20973889, 0.91272727, 0.13681932, 0.        , 0.66666667],
#        [0.671915  , 0.50181818, 0.22079752, 0.95      , 0.5       ],
#        ...,
#        [0.44508844, 0.50727273, 0.32862364, 0.5       , 0.44444444],
#        [0.86058827, 0.16727273, 0.24650346, 0.4       , 0.55555556],
#        [0.57988842, 0.00727273, 0.61743267, 0.45      , 0.38888889]])

# %%
# Scale on X_test
X_test_scaled = mms.fit_transform(X_test)
X_test_scaled
# Out:
# array([[0.83792852, 0.26459854, 0.31588187, 0.25      , 0.47058824],
#        [0.19998494, 0.92335766, 0.18620405, 0.525     , 0.82352941],
#        [0.63073911, 0.72262774, 0.63957043, 0.875     , 0.70588235],
#        ...,
#        [0.9095633 , 0.42153285, 0.57895498, 0.875     , 0.47058824],
#        [0.59588818, 0.89781022, 0.2366171 , 0.525     , 0.88235294],
#        [0.73928323, 0.55474453, 0.94531185, 0.875     , 0.58823529]])

# %%
# Importing the Required Libraries of Deep Learning
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam

# %%
# Built an Architecture of ANN
model = Sequential()

# Input Layer
model.add(Input(shape = (X_train.shape[1],)))

# Hidden Layer - 1
model.add(Dense(128, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.4))

# Hidden Layer - 2
model.add(Dense(64, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.3))

# Hidden Layer - 3
model.add(Dense(32, activation = 'relu'))
model.add(BatchNormalization())

# Output Layer
model.add(Dense(1, activation = 'sigmoid'))

# %%
# Call the Model
model
# Out:
# <Sequential name=sequential_2, built=True>

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_8 (Dense)                      │ (None, 128)                 │             768 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %%
# Compile the Model
model.compile(optimizer = Adam(learning_rate=0.0005), loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# Train the Model
history = model.fit(
    X_train_scaled, y_train,
    validation_data = (X_test_scaled, y_test),
    batch_size = 32,
    epochs = 100)
# Out:
# Epoch 1/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.6304 - loss: 0.6776 - val_accuracy: 0.4433 - val_loss: 0.6490
# Epoch 2/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8811 - loss: 0.2694 - val_accuracy: 0.8300 - val_loss: 0.5223
# Epoch 3/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9103 - loss: 0.2284 - val_accuracy: 0.9433 - val_loss: 0.3954
# Epoch 4/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9241 - loss: 0.1994 - val_accuracy: 0.9467 - val_loss: 0.3084
# Epoch 5/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9092 - loss: 0.2041 - val_accuracy: 0.9467 - val_loss: 0.2519
# Epoch 6/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9223 - loss: 0.1869 - val_accuracy: 0.9267 - val_loss: 0.2147
# Epoch 7/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9189 - loss: 0.1742 - val_accuracy: 0.9300 - val_loss: 0.1906
# Epoch 8/100
# ...

# %%
# Save the Scaler
import joblib

joblib.dump(mms, "models/scaler.pkl")
# Out:
# ['models/scaler.pkl']

# %%
# Visualize the Accuracy on both train and test
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Visualize the Loss on both train and test
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Save the Model
model.save("models/model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Evaluate the Model
train_loss, train_accuracy = model.evaluate(X_train, y_train)
print("Training Loss:", train_loss, "\nTraining Accuracy:", train_accuracy)

test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Testing Loss:", test_loss, "\nTesting Accuracy:", test_accuracy)
# Out:
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9989 - loss: 0.0080
# Training Loss: 0.008493676781654358
# Training Accuracy: 0.9994117617607117
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0127
# Testing Loss: 0.015794554725289345
# Testing Accuracy: 1.0
